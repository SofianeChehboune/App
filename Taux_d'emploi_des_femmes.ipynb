# %% [markdown]
# <a href="https://colab.research.google.com/github/SofianeChehboune/App/blob/main/Taux_d'emploi_des_femmes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *1/ Import Python Libraries*

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## *2 Load data from a CSV file*

# %%
df = pd.read_csv("/content/female-labor-force-participation-rates.csv")
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1991
# 1     Afghanistan  AFG  1992
# 2     Afghanistan  AFG  1993
# 3     Afghanistan  AFG  1994
# 4     Afghanistan  AFG  1995
# ...           ...  ...   ...
# 6625     Zimbabwe  ZWE  2019
# 6626     Zimbabwe  ZWE  2020
# 6627     Zimbabwe  ZWE  2021
# 6628     Zimbabwe  ZWE  2022
# 6629     Zimbabwe  ZWE  2023
#
#       Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)
# 0                                                15.635
# 1                                                15.698
# 2                                                15.715
# 3                                                15.726
# 4                                                15.796
# ...                                                 ...
# 6625                                             60.730
# 6626                                             59.848
# ...

# %% [markdown]
# ## 3/ *Data cleaning*

# %%
df.shape
# Out:
# (6630, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6630 entries, 0 to 6629
# Data columns (total 4 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Entity                                                                                           6630 non-null   object
#  1   Code                                                                                             6201 non-null   object
#  2   Year                                                                                             6630 non-null   int64
#  3   Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)  6630 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 207.3+ KB

# %%
df.isnull().sum()
# Out:
# Entity                                                                                               0
# Code                                                                                               429
# Year                                                                                                 0
# Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)      0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                                                      count         mean  \
# Year                                                6630.0  2006.992911
# Labor force participation rate, female (% of fe...  6630.0    49.620194
#
#                                                           std       min  \
# Year                                                 9.518936  1991.000
# Labor force participation rate, female (% of fe...  15.337242     4.828
#
#                                                            25%       50%  \
# Year                                                1999.00000  2007.000
# Labor force participation rate, female (% of fe...    41.85075    51.315
#
#                                                             75%       max
# Year                                                2015.000000  2023.000
# Labor force participation rate, female (% of fe...    59.272245    89.974

# %% [markdown]
# ## 4/ *Rename columns to simplify*

# %%
df.rename(columns={"Entity": "Pays",
                   "Year": "Année",
                   "Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)": "Taux d'emploi des femmes (%)"}, inplace=True)

# %%
df.head()
# Out:
#           Pays Code  Année  Taux d'emploi des femmes (%)
# 0  Afghanistan  AFG   1991                        15.635
# 1  Afghanistan  AFG   1992                        15.698
# 2  Afghanistan  AFG   1993                        15.715
# 3  Afghanistan  AFG   1994                        15.726
# 4  Afghanistan  AFG   1995                        15.796

# %% [markdown]
# ## 5/ *Creation of the animated graphic with Plotly for 500 first rows (https://plotly.com/)*

# %%
fig = px.bar(df.head(500),
             x="Taux d'emploi des femmes (%)",
             y="Pays",
             color="Pays",
             animation_frame="Année",
             orientation="h",
             title="Évolution du taux d'emploi des femmes (1991-2023)",
             range_x=[0, 100],  # Ajuste l'échelle si nécessaire
             width=1400,   # Largeur en pixels
             height=600)   # Hauteur en pixels

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 6/ *Creation of the animated graphic with Plotly for all Data*

# %%
fig = px.bar(df,
             x="Taux d'emploi des femmes (%)",
             y="Pays",
             color="Pays",
             animation_frame="Année",
             orientation="h",
             title="Évolution du taux d'emploi des femmes (1991-2023)",
             range_x=[0, 100],  # Ajuste l'échelle si nécessaire
             width=1400,   # Largeur en pixels
             height=600)   # Hauteur en pixels

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
